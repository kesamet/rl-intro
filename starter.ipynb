# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Chapter 2

# %%
from chapter02.ten_armed_testbed import figure_2_2

figure_2_2()
# Out:
# Bandit 0
#   Run 0
#   Run 1000
# Bandit 1
#   Run 0
#   Run 1000
# Bandit 2
#   Run 0
#   Run 1000

# %%
from chapter02.ten_armed_testbed import figure_2_3

figure_2_3()
# Out:
# Bandit 0
#   Run 0
#   Run 1000
# Bandit 1
#   Run 0
#   Run 1000

# %%
from chapter02.ten_armed_testbed import figure_2_4

figure_2_4()
# Out:
# Bandit 0
#   Run 0
#   Run 1000
# Bandit 1
#   Run 0
#   Run 1000

# %%
from chapter02.ten_armed_testbed import figure_2_5

figure_2_5()
# Out:
# Bandit 0
#   Run 0
#   Run 1000
# Bandit 1
#   Run 0
#   Run 1000
# Bandit 2
#   Run 0
#   Run 1000
# Bandit 3
#   Run 0
#   Run 1000

# %% [markdown]
# ## Chapter 3

# %%
from chapter03.gridworld import figure_3_2, figure_3_2_linear_system

figure_3_2()
figure_3_2_linear_system()

# %%
from chapter03.gridworld import figure_3_5

figure_3_5()

# %% [markdown]
# ## Chapter 4

# %%
from chapter04.gridworld import figure_4_1

figure_4_1()
# Out:
# In-place:
#   113 iterations
# Synchronous:
#   172 iterations

# %%
from chapter04.gambler import figure_4_3

figure_4_3()
# Out:
# No handles with labels found to put in legend.

# %%
[V1, pi1] = train(ph=0.4)
[V2, pi2] = train(ph=0.25)
[V3, pi3] = train(ph=0.55)
# Out:
# ph = 0.4000
#   train loop 874
#   Delta = 2.828444313936196e-07
#
# ph = 0.2500
#   train loop 180
#   Delta = 3.295510790236444e-07
#
# ph = 0.5500
#   train loop 1000
#   Delta = 0.2848966537408444
#   train loop 2000
#   Delta = 0.010589048408982116
#   train loop 3000
#   Delta = 0.0003755182175995131
#   train loop 4000
#   Delta = 8.12133620908817e-06
#   train loop 4442
#   Delta = 9.971674994613267e-07

# %%
S = np.linspace(1, 99, num=99, endpoint=True)
plt.figure()
plt.plot(S, V1, label="ph=0.40")
plt.plot(S, V2, label="ph=0.25")
plt.plot(S, V3, label="ph=0.55")
plt.legend()
plt.show()

# %%
plt.figure()
plt.bar(S, pi1)
plt.show()

plt.figure()
plt.bar(S, pi2)
plt.show()

plt.figure()
plt.bar(S, pi3)
plt.show()

# %%
from chapter04.car_rental import PolicyIteration

solver = PolicyIteration(delta=1e4, solve_4_7=True)
_ = solver.solve()
# Out:
# PE: iteration 0
#   - delta = 28292.743344591738
#   - delta = 25203.891186327273
#   - delta = 21905.129492766086
#   - delta = 18994.84955037721
#   - delta = 16479.91377158137
#   - delta = 14334.027562417168
#   - delta = 12518.28086367756
#   - delta = 10985.301876507796
#   - delta = 9686.400105590079
#   Values have converged!
#   Elapsed time: 75.77 seconds
# PI: iteration 0
#   Policy changed in 359 states
#   Elapsed time: 100.57 seconds
# PE: iteration 1
#   - delta = 12085.257081397625
#   - delta = 9154.427996265007
#   Values have converged!
#   Elapsed time: 20.85 seconds
# PI: iteration 1
#   Policy changed in 219 states
#   Elapsed time: 94.39 seconds
# PE: iteration 2
#   - delta = 7972.297989771036
#   Values have converged!
#   Elapsed time: 11.21 seconds
# PI: iteration 2
#   Policy changed in 55 states
#   Elapsed time: 98.10 seconds
# PE: iteration 3
#   - delta = 7060.855943740528
#   Values have converged!
#   Elapsed time: 9.67 seconds
# PI: iteration 3
# ...

# %% [markdown]
# ## Chapter 5

# %% [markdown]
# ## Chapter 6

# %%
from chapter06.random_walk import example_6_2

example_6_2()

# %%
from chapter06.windy_gridworld import figure_6_5

figure_6_5()

# %%
from chapter06.windy_gridworld import exercise_6_9

exercise_6_9()

# %%
from chapter06.windy_gridworld import exercise_6_10

exercise_6_10()

# %%
from chapter06.cliff_walk import example_6_6

example_6_6()

# %%
from chapter06.maximization_bias import figure_6_5

figure_6_5()

# %% [markdown]
# ## Chapter 7

# %%
from chapter07.random_walk import figure_7_2

figure_7_2()

# %% [markdown]
# ## Chapter 8

# %%
from chapter08.dyna_maze import figure_8_2

figure_8_2()
# Out:
# run: 0
# run: 1
# run: 2
# run: 3
# run: 4
# run: 5
# run: 6
# run: 7
# run: 8
# run: 9
